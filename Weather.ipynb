# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import data into pandas from CSV
path = 'C:\\Users\\tt66\\Desktop\\GWU Bootcamp\\HW\\10-Web (Week 12)\\Instructions\\Resources\\cities.csv'
weather_data = pd.read_csv(path)
weather_data.head(10)
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
# 5        5      martyush          92      RU  1528905306        94  56.40
# 6        6        hobart          20      AU  1528902000        87 -42.88
# 7        7   broken hill           0      AU  1528905311        88 -31.97
# 8        8     harnosand           0      SE  1528903200        44  62.63
# 9        9     tuatapere           0      NZ  1528905312       100 -46.13
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# ...

# %%
weather_data.plot.scatter(x="Lat", y="Max Temp",
                          c="red", s=50, edgecolors="black")
plt.title("City Latitude vs. Max Temp")
plt.savefig("C:\\Users\\tt66\\Desktop\\GWU Bootcamp\\HW\\10-Web (Week 12)\\Instructions\\Weather Images\\Temperature.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
weather_data.plot.scatter(x="Lat", y="Humidity",
                          c="yellow", s=50, edgecolors="black")
plt.title("City Latitude vs. Humidity")
plt.savefig("C:\\Users\\tt66\\Desktop\\GWU Bootcamp\\HW\\10-Web (Week 12)\\Instructions\\Weather Images\\Humidity.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
weather_data.plot.scatter(x="Lat", y="Cloudiness",
                          c="green", s=50, edgecolors="black")
plt.title("City Latitude vs. Cloudiness")
plt.savefig("C:\\Users\\tt66\\Desktop\\GWU Bootcamp\\HW\\10-Web (Week 12)\\Instructions\\Weather Images\\Cloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
weather_data.plot.scatter(x="Lat", y="Wind Speed",
                          c="purple", s=50, edgecolors="black")
plt.title("City Latitude vs. Wind Speed")
plt.savefig("C:\\Users\\tt66\\Desktop\\GWU Bootcamp\\HW\\10-Web (Week 12)\\Instructions\\Weather Images\\Wind Speed.png")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
